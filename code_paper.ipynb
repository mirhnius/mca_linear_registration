# %%
import pandas as pd
import numpy as np
import between_softwares_and_versions as bt
import matplotlib.pyplot as plt
from pathlib import Path
import seaborn as sns
import matplotlib as mpl
mpl.rcParams['font.size'] = 12

# %%
corratio = "/home/niusham/projects/rrg-glatard/niusham/mca_linear_registration/outputs_plots/flirt/MNI152NLin2009cAsym_res-01/corratio/reports/FD_MAD.csv"
normmi = "/home/niusham/projects/rrg-glatard/niusham/mca_linear_registration/outputs_plots/flirt/MNI152NLin2009cAsym_res-01/normmi/reports/FD_MAD.csv"
normcorr = "/home/niusham/projects/rrg-glatard/niusham/mca_linear_registration/outputs_plots/flirt/MNI152NLin2009cAsym_res-01/normcorr/reports/FD_MAD.csv"
mutualinfo = "/home/niusham/projects/rrg-glatard/niusham/mca_linear_registration/outputs_plots/flirt/MNI152NLin2009cAsym_res-01/mutualinfo/reports/FD_MAD.csv"

# %%
corratio_df = pd.read_csv(corratio)

normmi_df = pd.read_csv(normmi)
normcorr_df = pd.read_csv(normcorr)
mutualinfo_df = pd.read_csv(mutualinfo)
dfs = [corratio_df, normmi_df, normcorr_df, mutualinfo_df]

# %%
merged_df = dfs[0]  # Start with the first DataFrame
for df in dfs[1:]:
    # Drop or rename 'cohort' in df
    df = df.drop(columns=['cohort'])  # or rename
    merged_df = pd.merge(merged_df, df, on='Participant_ID')

# %%
fine_in_all = merged_df[(merged_df["QC_status_flirt_MNI152NLin2009cAsym_res-01_corratio"] == "fine")
          & (merged_df["QC_status_FLIRT_MNI152NLin2009cAsym_res-01_mutualinfo"] == "fine")
          & (merged_df["QC_status_FLIRT_MNI152NLin2009cAsym_res-01_normcorr"] == "fine")
          & (merged_df["QC_status_FLIRT_MNI152NLin2009cAsym_res-01_normmi"] == "fine")
]

# %%
from pathlib import Path
path = Path("/home/niusham/projects/rrg-glatard/niusham/mca_linear_registration/test_within/")
flirt_asym_df = pd.read_csv(path / "flirt/MNI152NLin2009cAsym_res-01/reports/FD_MAD.csv")
flirt_sym_df = pd.read_csv(path / "flirt/MNI152NLin2009cSym_res-1/reports/FD_MAD.csv")
ants_asym_df = pd.read_csv(path / "ants/MNI152NLin2009cAsym_res-01/reports/FD_MAD.csv")
ants_sym_df = pd.read_csv(path / "ants/MNI152NLin2009cSym_res-1/reports/FD_MAD.csv")
spm_asym_df = pd.read_csv(path / "spm/MNI152NLin2009cAsym_res-01/reports/FD_MAD.csv")
spm_sym_df = pd.read_csv(path / "spm/MNI152NLin2009cSym_res-1/reports/FD_MAD.csv")

# %%
dfs = [flirt_asym_df, flirt_sym_df, ants_asym_df,ants_sym_df,spm_asym_df,spm_sym_df]

# %%
merged_df = dfs[0]  # Start with the first DataFrame
for df in dfs[1:]:
    # Drop or rename 'cohort' in df
    df = df.drop(columns=['cohort'])  # or rename
    merged_df = pd.merge(merged_df, df, on='Participant_ID')

# %%
fine_in_all_asym = merged_df[(merged_df["QC_status_flirt_MNI152NLin2009cAsym_res-01"] == "fine")
          & (merged_df["QC_status_spm_MNI152NLin2009cAsym_res-01"] == "fine")
          & (merged_df["QC_status_ants_MNI152NLin2009cAsym_res-01"] == "fine")
]

# %%
merged_df
# Out:
#    Participant_ID  FD_std_flirt_MNI152NLin2009cAsym_res-01  \
# 0       sub-40882                                 0.061225
# 1      sub-179784                                 0.052101
# 2       sub-75562                                 0.026760
# 3        sub-3001                                 0.013878
# 4        sub-3078                                 0.048364
# ..            ...                                      ...
# 95       sub-3709                                 0.153446
# 96       sub-3700                                 0.134799
# 97       sub-3403                                 0.928398
# 98     sub-116230                                 0.155635
# 99       sub-3620                                 0.149529
#
#     MAD_flirt_MNI152NLin2009cAsym_res-01  \
# 0                               0.057676
# 1                               0.063449
# 2                               0.027624
# 3                               0.044102
# 4                               0.045767
# ...

# %%
fine_in_all_sym = merged_df[(merged_df["QC_status_flirt_MNI152NLin2009cSym_res-1"] == "fine")
          & (merged_df["QC_status_spm_MNI152NLin2009cSym_res-1"] == "fine")
          & (merged_df["QC_status_ants_MNI152NLin2009cSym_res-1"] == "fine")
]

# %%
merged_df
# Out:
#    Participant_ID  FD_std_flirt_MNI152NLin2009cAsym_res-01  \
# 0       sub-40882                                 0.061225
# 1      sub-179784                                 0.052101
# 2       sub-75562                                 0.026760
# 3        sub-3001                                 0.013878
# 4        sub-3078                                 0.048364
# ..            ...                                      ...
# 95       sub-3709                                 0.153446
# 96       sub-3700                                 0.134799
# 97       sub-3403                                 0.928398
# 98     sub-116230                                 0.155635
# 99       sub-3620                                 0.149529
#
#     MAD_flirt_MNI152NLin2009cAsym_res-01  \
# 0                               0.057676
# 1                               0.063449
# 2                               0.027624
# 3                               0.044102
# 4                               0.045767
# ...

# %%
full_df = fine_in_all[["FD_std_FLIRT_MNI152NLin2009cAsym_res-01_mutualinfo", "FD_std_FLIRT_MNI152NLin2009cAsym_res-01_normmi", "FD_std_FLIRT_MNI152NLin2009cAsym_res-01_normcorr", "FD_std_flirt_MNI152NLin2009cAsym_res-01_corratio"]]

# %%
full_df = fine_in_all[["FD_std_FLIRT_MNI152NLin2009cAsym_res-01_mutualinfo", "FD_std_FLIRT_MNI152NLin2009cAsym_res-01_normmi", "FD_std_FLIRT_MNI152NLin2009cAsym_res-01_normcorr", "FD_std_flirt_MNI152NLin2009cAsym_res-01_corratio"]]
full_df.columns = ["MI", "NMI", "NCC", "CR"]
full_df = full_df.melt(var_name="Cost Function", value_name="FD_std")
full_df["FD_std"] = np.log10(full_df["FD_std"])

# %%
# Set the aesthetic style of the plots
# sns.set(style="whitegrid")

# Create the swarm plot
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
sns.swarmplot(x='Cost Function', y='FD_std', data=full_df, palette=["#9ACD32", "#90ee0d", "#90eeb3", "#90ee90"])
sns.boxplot(x='Cost Function', y='FD_std', data=full_df, color="white")
# Adding titles and labels
# plt.title('Standard Deviation of Framewise Displacement for Different Similarity Measures in FLIRT')
plt.xlabel('')
plt.ylabel('log10(value) (mm)')
plt.xticks(range(4), labels=["MI","NMI", "NCC","CR"])
sns.despine(top=True, right=True)

# Display the plot
plt.savefig("./paper_figures/paper_similarity_fig.pdf", format='pdf', bbox_inches='tight')
# Out:
# /tmp/ipykernel_3163435/838462644.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x='Cost Function', y='FD_std', data=full_df, palette=["#9ACD32", "#90ee0d", "#90eeb3", "#90ee90"])

# %%
from pathlib import Path
path = Path("/home/niusham/projects/rrg-glatard/niusham/mca_linear_registration/test_within/")
flirt_asym_df = pd.read_csv(path / "flirt/MNI152NLin2009cAsym_res-01/reports/FD_MAD.csv")
flirt_sym_df = pd.read_csv(path / "flirt/MNI152NLin2009cSym_res-1/reports/FD_MAD.csv")
ants_asym_df = pd.read_csv(path / "ants/MNI152NLin2009cAsym_res-01/reports/FD_MAD.csv")
ants_sym_df = pd.read_csv(path / "ants/MNI152NLin2009cSym_res-1/reports/FD_MAD.csv")
spm_asym_df = pd.read_csv(path / "spm/MNI152NLin2009cAsym_res-01/reports/FD_MAD.csv")
spm_sym_df = pd.read_csv(path / "spm/MNI152NLin2009cSym_res-1/reports/FD_MAD.csv")

# %%
dfs = [flirt_asym_df, flirt_sym_df, ants_asym_df,ants_sym_df,spm_asym_df,spm_sym_df]

# %%
new_labels = ["SPM-Asym", "FLIRT-Asym", "ANTS-Asym", "SPM-Sym","FLIRT-Sym", "ANTS-Sym"]

# %%
merged_df = dfs[0]  # Start with the first DataFrame
for df in dfs[1:]:
    # Drop or rename 'cohort' in df
    df = df.drop(columns=['cohort'])  # or rename
    merged_df = pd.merge(merged_df, df, on='Participant_ID')

# %%
merged_df
# Out:
#    Participant_ID  FD_std_flirt_MNI152NLin2009cAsym_res-01  \
# 0       sub-40882                                 0.061225
# 1      sub-179784                                 0.052101
# 2       sub-75562                                 0.026760
# 3        sub-3001                                 0.013878
# 4        sub-3078                                 0.048364
# ..            ...                                      ...
# 95       sub-3709                                 0.153446
# 96       sub-3700                                 0.134799
# 97       sub-3403                                 0.928398
# 98     sub-116230                                 0.155635
# 99       sub-3620                                 0.149529
#
#     MAD_flirt_MNI152NLin2009cAsym_res-01  \
# 0                               0.057676
# 1                               0.063449
# 2                               0.027624
# 3                               0.044102
# 4                               0.045767
# ...

# %%
sd_fd_flirt_asym = np.log10(flirt_asym_df[flirt_asym_df["QC_status_flirt_MNI152NLin2009cAsym_res-01"] == "fine"]["FD_std_flirt_MNI152NLin2009cAsym_res-01"])
sd_fd_flirt_sym = np.log10(flirt_sym_df[flirt_sym_df["QC_status_flirt_MNI152NLin2009cSym_res-1"] == "fine"]["FD_std_flirt_MNI152NLin2009cSym_res-1"])

sd_fd_spm_asym = np.log10(spm_asym_df[spm_asym_df["QC_status_spm_MNI152NLin2009cAsym_res-01"] == "fine"]["FD_std_spm_MNI152NLin2009cAsym_res-01"])
sd_fd_spm_sym = np.log10(spm_sym_df[spm_sym_df["QC_status_spm_MNI152NLin2009cSym_res-1"] == "fine"]["FD_std_spm_MNI152NLin2009cSym_res-1"])

sd_fd_ants_asym = np.log10(ants_asym_df[ants_asym_df["QC_status_ants_MNI152NLin2009cAsym_res-01"] == "fine"]["FD_std_ants_MNI152NLin2009cAsym_res-01"])
sd_fd_ants_sym = np.log10(ants_sym_df[ants_sym_df["QC_status_ants_MNI152NLin2009cSym_res-1"] == "fine"]["FD_std_ants_MNI152NLin2009cSym_res-1"])

# %%
sd_fd_flirt_asym.name = 'value'
sd_fd_flirt_sym.name = 'value'
sd_fd_spm_asym.name = 'value'
sd_fd_spm_sym.name = 'value'
sd_fd_ants_asym.name = 'value'
sd_fd_ants_sym.name = 'value'

dfs = [
    pd.DataFrame({'value': sd_fd_spm_asym, 'software - template': 'SPM - Asym'}),
    pd.DataFrame({'value': sd_fd_spm_sym, 'software - template': 'SPM - Sym'}),
    pd.DataFrame({'value': sd_fd_flirt_asym, 'software - template': 'FLIRT - Asym'}),
    pd.DataFrame({'value': sd_fd_flirt_sym, 'software - template': 'FLIRT - Sym'}),
    pd.DataFrame({'value': sd_fd_ants_asym, 'software - template': 'ANTs - Asym'}),
    pd.DataFrame({'value': sd_fd_ants_sym, 'software - template': 'ANTs - Sym'})
]

# Combine them
all_data = pd.concat(dfs, ignore_index=True)

# %%
# merged_df[(merged_df["QC_status_spm_MNI152NLin2009cAsym_res-01"] == "fine")
#           & (merged_df["QC_status_flirt_MNI152NLin2009cAsym_res-01"] == "fine")
#           & (merged_df["QC_status_ants_MNI152NLin2009cAsym_res-01"] == "fine")
#           & (merged_df["QC_status_spm_MNI152NLin2009cSym_res-1"] == "fine")
#           & (merged_df["QC_status_flirt_MNI152NLin2009cSym_res-1"] == "fine")
#           & (merged_df["QC_status_ants_MNI152NLin2009cSym_res-1"] == "fine")
# ]

# %%
# fine_in_all.columns = new_labels

# %%
# Order labels
labels = ['SPM - Asym', 'SPM - Sym', 'FLIRT - Asym', 'FLIRT - Sym', 'ANTs - Asym', 'ANTs - Sym']
all_data['software - template'] = pd.Categorical(all_data['software - template'], categories=labels, ordered=True)

# Color palette
color_palette = {
    'SPM - Asym': '#dda0dd',
    'SPM - Sym': '#800080',
    'FLIRT - Asym': '#90ee90',
    'FLIRT - Sym': '#008000',
    'ANTs - Asym': '#cd5c5c',
    'ANTs - Sym': '#8b0000'
}
medians = all_data.groupby('software - template')['value'].median()
plt.figure(figsize=(10, 6))
sns.swarmplot(x='software - template', y='value', data=all_data, size=3, palette=color_palette)
sns.boxplot(x='software - template', y='value', data=all_data, color="white")
for i, median in enumerate(medians.keys()):
     plt.text(i, -5.3, f"median: {medians[median]:.2f}", fontsize=12, rotation=90)
#medians[median] - 1
# plt.title('Standard Deviation of Frame-Wise Displacement Across MCA Runs for Passed QC Subjects')
plt.ylabel('log10(value) (mm)')
plt.xticks(ticks=list(range(6)), rotation=45, labels=labels)
plt.xlabel('')
sns.despine(top=True, right=True)
plt.savefig('./paper_figures/sd_fd_all.pdf', format='pdf', bbox_inches='tight')
# Out:
# /tmp/ipykernel_3163435/291995428.py:14: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   medians = all_data.groupby('software - template')['value'].median()
# /tmp/ipykernel_3163435/291995428.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x='software - template', y='value', data=all_data, size=3, palette=color_palette)
# /home/niusham/projects/rrg-jbpoline/niusham/mca_linear_registration/.venv/lib/python3.11/site-packages/seaborn/categorical.py:3399: UserWarning: 5.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
flirt_asym_df
# Out:
#    Participant_ID  FD_std_flirt_MNI152NLin2009cAsym_res-01  \
# 0       sub-40882                                 0.061225
# 1      sub-179784                                 0.052101
# 2       sub-75562                                 0.026760
# 3        sub-3001                                 0.013878
# 4        sub-3078                                 0.048364
# ..            ...                                      ...
# 95       sub-3709                                 0.153446
# 96       sub-3700                                 0.134799
# 97       sub-3403                                 0.928398
# 98     sub-116230                                 0.155635
# 99       sub-3620                                 0.149529
#
#     MAD_flirt_MNI152NLin2009cAsym_res-01  \
# 0                               0.057676
# 1                               0.063449
# 2                               0.027624
# 3                               0.044102
# 4                               0.045767
# ...

# %%
# palette_colors = {
#     SPM: {MNI2009cAsym: "#dda0dd", MNI2009cSym: "#800080"},
#     ANTS: {MNI2009cAsym: "#cd5c5c", MNI2009cSym: "#8b0000"},
#     FLIRT: {MNI2009cAsym: "#90ee90", MNI2009cSym: "#008000"},
# }
# failed_palette_colors = {
#     SPM: {
#         MNI2009cAsym: "#d0dda0",  # Complementary to light purple (yellowish-green)
#         MNI2009cSym: "#808000",  # Complementary to dark purple (olive green)
#     },
#     ANTS: {
#         MNI2009cAsym: "#5ccdc5",  # Complementary to red (cyan)
#         MNI2009cSym: "#00008b",  # Complementary to dark red (navy blue)
#     },
#     FLIRT: {
#         MNI2009cAsym: "#ee9090",  # Complementary to light green (light red)
#         MNI2009cSym: "#800000",  # Complementary to dark green (maroon)
#     },
# }

# %%
passed = flirt_asym_df[flirt_asym_df["QC_status_flirt_MNI152NLin2009cAsym_res-01"] == "fine"]["FD_std_flirt_MNI152NLin2009cAsym_res-01"]
failed = flirt_asym_df[flirt_asym_df["QC_status_flirt_MNI152NLin2009cAsym_res-01"] == "failed"]["FD_std_flirt_MNI152NLin2009cAsym_res-01"]

# %%
plt.figure(figsize=(3,4))
sns.swarmplot(np.log10(passed), color="#90ee90")
sns.swarmplot(np.log10(failed), color="b")
# title = "Standard deviation of FD: Comparing Passed and Failed QC Subjects"
# plt.title(title)
# cost_function = "default" if cost_function is None else cost_function
plt.ylabel("log10(value) (mm)")
# plt.xlabel(f"{software.upper()}-{template}-{cost_function}")
plt.xlabel("FLIRT - Asym")
plt.legend(["Passed QC", "Failed QC"])
sns.despine(top=True, right=True)
plt.savefig('./paper_figures/sq_qc_flirt.pdf', format='pdf', bbox_inches='tight')

# %%
passed = spm_asym_df[spm_asym_df["QC_status_spm_MNI152NLin2009cAsym_res-01"] == "fine"]["FD_std_spm_MNI152NLin2009cAsym_res-01"]
failed = spm_asym_df[spm_asym_df["QC_status_spm_MNI152NLin2009cAsym_res-01"] == "failed"]["FD_std_spm_MNI152NLin2009cAsym_res-01"]

# %%
plt.figure(figsize=(3,4))
sns.swarmplot(np.log10(passed), color="#dda0dd")
sns.swarmplot(np.log10(failed), color="b")
# title = "Standard deviation of FD: Comparing Passed and Failed QC Subjects"
# plt.title(title)
# cost_function = "default" if cost_function is None else cost_function
plt.ylabel("log10(value) (mm)")
# plt.xlabel(f"{software.upper()}-{template}-{cost_function}")
plt.xlabel("SPM - Asym")
plt.legend(["Passed QC", "Failed QC"])
sns.despine(top=True, right=True)
plt.savefig('./paper_figures/sq_qc_spm.pdf', format='pdf', bbox_inches='tight')

# %%
passed = ants_asym_df[ants_asym_df["QC_status_ants_MNI152NLin2009cAsym_res-01"] == "fine"]["FD_std_ants_MNI152NLin2009cAsym_res-01"]
failed = ants_asym_df[ants_asym_df["QC_status_ants_MNI152NLin2009cAsym_res-01"] == "failed"]["FD_std_ants_MNI152NLin2009cAsym_res-01"]

# %%
plt.figure(figsize=(3,4))
sns.swarmplot(np.log10(passed), color="#cd5c5c")
sns.swarmplot(np.log10(failed), color="b")
# title = "Standard deviation of FD: Comparing Passed and Failed QC Subjects"
# plt.title(title)
# cost_function = "default" if cost_function is None else cost_function
plt.ylabel("log10(value) (mm)")
# plt.xlabel(f"{software.upper()}-{template}-{cost_function}")
plt.xlabel("ANTs - Asym")
plt.legend(["Passed QC", "Failed QC"])
sns.despine(top=True, right=True)
plt.savefig('./paper_figures/sq_qc_ants.pdf', format='pdf', bbox_inches='tight')

# %%
b_p = set(ants_asym_df[(ants_asym_df["QC_status_ants_MNI152NLin2009cAsym_res-01"]=="fine")]["Participant_ID"])
a_p = set(mutualinfo_df[(mutualinfo_df["QC_status_FLIRT_MNI152NLin2009cAsym_res-01_mutualinfo"]=="fine")]["Participant_ID"])
patient_list = list(a_p & b_p)
a = mutualinfo_df[(mutualinfo_df["QC_status_FLIRT_MNI152NLin2009cAsym_res-01_mutualinfo"]=="fine")&(mutualinfo_df["Participant_ID"].isin(patient_list))]["FD_std_FLIRT_MNI152NLin2009cAsym_res-01_mutualinfo"]
b=ants_asym_df[
    (ants_asym_df["QC_status_ants_MNI152NLin2009cAsym_res-01"] == "fine") &
    (ants_asym_df["Participant_ID"].isin(patient_list))
]["FD_std_ants_MNI152NLin2009cAsym_res-01"]

# %%
from scipy.stats import wilcoxon

# %%
wilcoxon(a,b)
# Out:
# WilcoxonResult(statistic=366.0, pvalue=3.1339167800133824e-12)

# %%
mutualinfo_df.rename(columns={"FD_std_FLIRT_MNI152NLin2009cAsym_res-01_mutualinfo":"value"}, inplace=True)
mutualinfo_df['value'] = np.log10(mutualinfo_df['value'])
mutualinfo_df['pipeline'] = "FLIRT"
mutualinfo_fine_df = mutualinfo_df[(mutualinfo_df["QC_status_FLIRT_MNI152NLin2009cAsym_res-01_mutualinfo"]=="fine")]


ants_asym_df.rename(columns={"FD_std_ants_MNI152NLin2009cAsym_res-01":"value"}, inplace=True)
ants_asym_df['value'] = np.log10(ants_asym_df['value'])
ants_asym_df['pipeline'] = "ANTs"
ants_asym_fine_df = ants_asym_df[(ants_asym_df["QC_status_ants_MNI152NLin2009cAsym_res-01"] == "fine")]


mi_compare = pd.concat([mutualinfo_fine_df[['pipeline','value']], ants_asym_fine_df[['pipeline','value']]])

# %%
ants_asym_df
# Out:
#    Participant_ID     value  MAD_ants_MNI152NLin2009cAsym_res-01  \
# 0       sub-40882 -1.200110                             0.062016
# 1      sub-179784 -1.191336                             0.052990
# 2       sub-75562 -1.073721                             0.062666
# 3        sub-3001 -1.280481                             0.107096
# 4        sub-3078 -1.241961                             0.047978
# ..            ...       ...                                  ...
# 95       sub-3112 -1.284752                             0.053317
# 96       sub-3157 -1.013239                             0.087295
# 97       sub-3852 -1.139700                             0.080432
# 98     sub-116230  1.055566                             7.831633
# 99       sub-3620  1.038857                            11.031588
#
#    QC_status_ants_MNI152NLin2009cAsym_res-01 cohort pipeline
# 0                                       fine     PD     ANTs
# 1                                       fine     PD     ANTs
# ...

# %%
color_palette = {
    'FLIRT':"#9ACD32",
    
    'ANTs': '#cd5c5c',
}

plt.figure(figsize=(3, 5))
sns.swarmplot(x='pipeline', y='value', data=mi_compare, size=3, palette=color_palette)
sns.boxplot(x='pipeline', y='value', data=mi_compare, color="white")

plt.ylabel('log10(value) (mm)')
plt.xticks(ticks=list(range(2)), rotation=0, labels=["FLIRT", "ANTs"])
plt.xlabel('')
sns.despine(top=True, right=True)
plt.savefig('./paper_figures/mi_compare.pdf', format='pdf', bbox_inches='tight')
# Out:
# /tmp/ipykernel_3163435/139154849.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x='pipeline', y='value', data=mi_compare, size=3, palette=color_palette)

# %%
verou_df = pd.read_csv("/home/niusham/projects/rrg-glatard/niusham/mca_linear_registration/verrou_plots/spm/MNI152NLin2009cAsym_res-01/reports/FD_MAD.csv")

# %%
verou_df.rename(columns={"FD_std_spm_MNI152NLin2009cAsym_res-01":"value"}, inplace=True)
verou_df['value'] = np.log10(verou_df['value'])
verou_df['pipeline'] = "Verrou"

spm_asym_df.rename(columns={"FD_std_spm_MNI152NLin2009cAsym_res-01":"value"}, inplace=True)
spm_asym_df['value'] = np.log10(spm_asym_df['value'])
spm_asym_df['pipeline'] = "Verificarlo"

# %%
spm_compare = pd.concat([verou_df[['pipeline','value']], spm_asym_df[['pipeline','value']]])

# %%
color_palette = {
    'FLIRT':"#9ACD32",
    
    'ANTs': '#cd5c5c',
}

plt.figure(figsize=(3, 5))
sns.swarmplot(x='pipeline', y='value', data=spm_compare, size=3, palette=['#FFB6C1', '#dda0dd'])
sns.boxplot(x='pipeline', y='value', data=spm_compare, color="white")

plt.ylabel('log10(value) (mm)')
plt.xticks(ticks=list(range(2)), rotation=0, labels=["Verrou", "Verificarlo"])
plt.xlabel('')
sns.despine(top=True, right=True)
plt.savefig('./paper_figures/spm_compare.pdf', format='pdf', bbox_inches='tight')
# Out:
# /tmp/ipykernel_3163435/3268447418.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x='pipeline', y='value', data=spm_compare, size=3, palette=['#FFB6C1', '#dda0dd'])

# %%
from pathlib import Path
path = Path("/home/niusham/projects/rrg-glatard/niusham/mca_linear_registration/test_within/")
flirt_asym_df = pd.read_csv(path / "flirt/MNI152NLin2009cAsym_res-01/reports/FD_MAD.csv")
flirt_sym_df = pd.read_csv(path / "flirt/MNI152NLin2009cSym_res-1/reports/FD_MAD.csv")
ants_asym_df = pd.read_csv(path / "ants/MNI152NLin2009cAsym_res-01/reports/FD_MAD.csv")
ants_sym_df = pd.read_csv(path / "ants/MNI152NLin2009cSym_res-1/reports/FD_MAD.csv")
spm_asym_df = pd.read_csv(path / "spm/MNI152NLin2009cAsym_res-01/reports/FD_MAD.csv")
spm_sym_df = pd.read_csv(path / "spm/MNI152NLin2009cSym_res-1/reports/FD_MAD.csv")

# %%
ants_asym_df[ants_asym_df['FD_std_ants_MNI152NLin2009cAsym_res-01'] > 0.2]
# Out:
#    Participant_ID  FD_std_ants_MNI152NLin2009cAsym_res-01  \
# 11       sub-3586                                3.100581
# 15      sub-42264                                3.501567
# 18       sub-3365                               12.712657
# 59       sub-3969                                9.594427
# 98     sub-116230                               11.364920
# 99       sub-3620                               10.935974
#
#     MAD_ants_MNI152NLin2009cAsym_res-01  \
# 11                             1.154587
# 15                             1.307905
# 18                             8.310506
# 59                             9.773278
# 98                             7.831633
# 99                            11.031588
#
#    QC_status_ants_MNI152NLin2009cAsym_res-01 cohort
# 11                                      fine     PD
# 15                                      fine     PD
# 18                                      fine     PD
# 59                                      fine     HC
# ...

# %%
np.median(ants_asym_df[ants_asym_df['QC_status_ants_MNI152NLin2009cAsym_res-01'] == "fine"]['FD_std_ants_MNI152NLin2009cAsym_res-01'])
# Out:
# 0.0680193427710617

# %%
np.mean(ants_asym_df[ants_asym_df['QC_status_ants_MNI152NLin2009cAsym_res-01'] == "failed"]['FD_std_ants_MNI152NLin2009cAsym_res-01'])
# Out:
# 11.150446568950514

# %%
ants_sym_df[ants_sym_df["FD_std_ants_MNI152NLin2009cSym_res-1"]>0.2]
# Out:
#    Participant_ID  FD_std_ants_MNI152NLin2009cSym_res-1  \
# 18       sub-3365                             12.261031
# 41       sub-3970                             10.666394
# 84       sub-3620                              8.357388
# 98     sub-116230                             12.978348
# 99       sub-3969                              9.710393
#
#     MAD_ants_MNI152NLin2009cSym_res-1 QC_status_ants_MNI152NLin2009cSym_res-1  \
# 18                           6.221022                                    fine
# 41                           3.747641                                    fine
# 84                           9.484427                                    fine
# 98                          13.166702                                  failed
# 99                          13.395550                                  failed
#
#    cohort
# 18     PD
# 41     PD
# 84     HC
# 98     HC
# 99     HC

# %%
np.mean(ants_sym_df[ants_sym_df["QC_status_ants_MNI152NLin2009cSym_res-1"] == "fine"]["FD_std_ants_MNI152NLin2009cSym_res-1"])
# Out:
# 0.38750956966705635

# %%
np.mean(ants_sym_df[ants_sym_df["QC_status_ants_MNI152NLin2009cSym_res-1"] == "failed"]["FD_std_ants_MNI152NLin2009cSym_res-1"])
# Out:
# 11.344370743316883

# %%
spm_asym_df[spm_asym_df['FD_std_spm_MNI152NLin2009cAsym_res-01'] > 0.2]
# Out:
# Empty DataFrame
# Columns: [Participant_ID, FD_std_spm_MNI152NLin2009cAsym_res-01, MAD_spm_MNI152NLin2009cAsym_res-01, QC_status_spm_MNI152NLin2009cAsym_res-01, cohort]
# Index: []

# %%
spm_asym_df
# Out:
#    Participant_ID  FD_std_spm_MNI152NLin2009cAsym_res-01  \
# 0       sub-40882                           3.438953e-09
# 1      sub-179784                           3.310995e-09
# 2        sub-3001                           1.622609e-09
# 3        sub-3078                           2.970846e-10
# 4      sub-130156                           7.593429e-11
# ..            ...                                    ...
# 95       sub-3811                           4.883415e-08
# 96       sub-3853                           2.072535e-08
# 97       sub-3969                           9.968460e-08
# 98       sub-4067                           1.891166e-09
# 99       sub-4079                           5.782010e-08
#
#     MAD_spm_MNI152NLin2009cAsym_res-01  \
# 0                         3.975848e-09
# 1                         3.238402e-09
# 2                         1.489641e-09
# 3                         2.760029e-10
# 4                         9.230803e-11
# ...

# %%
np.median(spm_asym_df[spm_asym_df['QC_status_spm_MNI152NLin2009cAsym_res-01'] == "fine"]['FD_std_spm_MNI152NLin2009cAsym_res-01'])
# Out:
# 1.7418913335734988e-09

# %%
np.median(spm_asym_df[spm_asym_df['QC_status_spm_MNI152NLin2009cAsym_res-01'] == "failed"]['FD_std_spm_MNI152NLin2009cAsym_res-01'])
# Out:
# 3.587987773452702e-08

# %%
spm_sym_df[spm_sym_df['FD_std_spm_MNI152NLin2009cSym_res-1'] > 0.2]
# Out:
# Empty DataFrame
# Columns: [Participant_ID, FD_std_spm_MNI152NLin2009cSym_res-1, MAD_spm_MNI152NLin2009cSym_res-1, QC_status_spm_MNI152NLin2009cSym_res-1, cohort]
# Index: []

# %%
np.mean(spm_sym_df[spm_sym_df['QC_status_spm_MNI152NLin2009cSym_res-1'] == "fine"]['FD_std_spm_MNI152NLin2009cSym_res-1'])
# Out:
# 6.11706876393039e-09

# %%
np.mean(spm_sym_df[spm_sym_df['QC_status_spm_MNI152NLin2009cSym_res-1'] == "failed"]['FD_std_spm_MNI152NLin2009cSym_res-1'])
# Out:
# 9.680502638993666e-08

# %%
flirt_asym_df
# Out:
#    Participant_ID  FD_std_flirt_MNI152NLin2009cAsym_res-01  \
# 0       sub-40882                                 0.061225
# 1      sub-179784                                 0.052101
# 2       sub-75562                                 0.026760
# 3        sub-3001                                 0.013878
# 4        sub-3078                                 0.048364
# ..            ...                                      ...
# 95       sub-3709                                 0.153446
# 96       sub-3700                                 0.134799
# 97       sub-3403                                 0.928398
# 98     sub-116230                                 0.155635
# 99       sub-3620                                 0.149529
#
#     MAD_flirt_MNI152NLin2009cAsym_res-01  \
# 0                               0.057676
# 1                               0.063449
# 2                               0.027624
# 3                               0.044102
# 4                               0.045767
# ...

# %%
flirt_asym_df[flirt_asym_df["FD_std_flirt_MNI152NLin2009cAsym_res-01"]>0.2]
# Out:
#    Participant_ID  FD_std_flirt_MNI152NLin2009cAsym_res-01  \
# 36     sub-121830                                 0.224263
# 97       sub-3403                                 0.928398
#
#     MAD_flirt_MNI152NLin2009cAsym_res-01  \
# 36                              0.168681
# 97                              2.783429
#
#    QC_status_flirt_MNI152NLin2009cAsym_res-01 cohort
# 36                                       fine     PD
# 97                                     failed     PD

# %%
np.median(flirt_asym_df[flirt_asym_df["QC_status_flirt_MNI152NLin2009cAsym_res-01"] == "fine"]["FD_std_flirt_MNI152NLin2009cAsym_res-01"])
# Out:
# 0.0497321825001191

# %%
np.mean(flirt_asym_df[flirt_asym_df["QC_status_flirt_MNI152NLin2009cAsym_res-01"] == "failed"]["FD_std_flirt_MNI152NLin2009cAsym_res-01"])
# Out:
# 0.30436139908169746

# %%
flirt_sym_df[flirt_sym_df["FD_std_flirt_MNI152NLin2009cSym_res-1"]>0.2]
# Out:
#    Participant_ID  FD_std_flirt_MNI152NLin2009cSym_res-1  \
# 94       sub-3403                               1.093538
# 95       sub-3700                               0.229696
# 98       sub-3620                               0.748862
#
#     MAD_flirt_MNI152NLin2009cSym_res-1  \
# 94                            1.774050
# 95                            0.222623
# 98                            0.622919
#
#    QC_status_flirt_MNI152NLin2009cSym_res-1 cohort
# 94                                   failed     PD
# 95                                   failed     PD
# 98                                   failed     HC

# %%
np.mean(flirt_sym_df[flirt_sym_df["QC_status_flirt_MNI152NLin2009cSym_res-1"] == "fine"]["FD_std_flirt_MNI152NLin2009cSym_res-1"])
# Out:
# 0.05426002638032808

# %%
np.mean(flirt_sym_df[flirt_sym_df["QC_status_flirt_MNI152NLin2009cSym_res-1"] == "failed"]["FD_std_flirt_MNI152NLin2009cSym_res-1"])
# Out:
# 0.3793714215577965

# %%
corratio = "/home/niusham/projects/rrg-glatard/niusham/mca_linear_registration/outputs_plots/flirt/MNI152NLin2009cAsym_res-01/corratio/reports/FD_MAD.csv"
normmi = "/home/niusham/projects/rrg-glatard/niusham/mca_linear_registration/outputs_plots/flirt/MNI152NLin2009cAsym_res-01/normmi/reports/FD_MAD.csv"
normcorr = "/home/niusham/projects/rrg-glatard/niusham/mca_linear_registration/outputs_plots/flirt/MNI152NLin2009cAsym_res-01/normcorr/reports/FD_MAD.csv"
mutualinfo = "/home/niusham/projects/rrg-glatard/niusham/mca_linear_registration/outputs_plots/flirt/MNI152NLin2009cAsym_res-01/mutualinfo/reports/FD_MAD.csv"

# %%
normcorr_df
# Out:
#    Participant_ID  FD_std_FLIRT_MNI152NLin2009cAsym_res-01_normcorr  \
# 0       sub-40882                                          0.034352
# 1      sub-179784                                          0.026866
# 2       sub-75562                                          0.017651
# 3        sub-3001                                          0.015791
# 4        sub-3078                                          0.035090
# ..            ...                                               ...
# 95       sub-3700                                          0.138380
# 96       sub-3403                                        112.241258
# 97      sub-40733                                          0.046978
# 98     sub-116230                                          0.111927
# 99       sub-3620                                          0.268801
#
#     MAD_FLIRT_MNI152NLin2009cAsym_res-01_normcorr  \
# 0                                        0.030965
# ...

# %%
flirt_asym_df
# Out:
#    Participant_ID  FD_std_flirt_MNI152NLin2009cAsym_res-01  \
# 0       sub-40882                                 0.061225
# 1      sub-179784                                 0.052101
# 2       sub-75562                                 0.026760
# 3        sub-3001                                 0.013878
# 4        sub-3078                                 0.048364
# ..            ...                                      ...
# 95       sub-3709                                 0.153446
# 96       sub-3700                                 0.134799
# 97       sub-3403                                 0.928398
# 98     sub-116230                                 0.155635
# 99       sub-3620                                 0.149529
#
#     MAD_flirt_MNI152NLin2009cAsym_res-01  \
# 0                               0.057676
# 1                               0.063449
# 2                               0.027624
# 3                               0.044102
# 4                               0.045767
# ...

# %%
corratio_df = pd.read_csv(corratio)

normmi_df = pd.read_csv(normmi)
normcorr_df = pd.read_csv(normcorr)
mutualinfo_df = pd.read_csv(mutualinfo)
dfs = [corratio_df, normmi_df, normcorr_df, mutualinfo_df]

# %%
normcorr_df[normcorr_df["FD_std_FLIRT_MNI152NLin2009cAsym_res-01_normcorr"] > 0.2]
# Out:
#    Participant_ID  FD_std_FLIRT_MNI152NLin2009cAsym_res-01_normcorr  \
# 94       sub-3709                                          0.362625
# 96       sub-3403                                        112.241258
# 99       sub-3620                                          0.268801
#
#     MAD_FLIRT_MNI152NLin2009cAsym_res-01_normcorr  \
# 94                                       0.429553
# 96                                      39.083019
# 99                                       0.252074
#
#    QC_status_FLIRT_MNI152NLin2009cAsym_res-01_normcorr cohort
# 94                                             failed      PD
# 96                                             failed      PD
# 99                                             failed      HC

# %%
np.mean(normcorr_df[normcorr_df["QC_status_FLIRT_MNI152NLin2009cAsym_res-01_normcorr"] == "fine"]["FD_std_FLIRT_MNI152NLin2009cAsym_res-01_normcorr"])
# Out:
# 0.029137282890813014

# %%
np.mean(normcorr_df[normcorr_df["QC_status_FLIRT_MNI152NLin2009cAsym_res-01_normcorr"] == "failed"]["FD_std_FLIRT_MNI152NLin2009cAsym_res-01_normcorr"])
# Out:
# 18.861661385093218

# %%
normcorr_df[normcorr_df["QC_status_FLIRT_MNI152NLin2009cAsym_res-01_normcorr"] == "failed"]
# Out:
#    Participant_ID  FD_std_FLIRT_MNI152NLin2009cAsym_res-01_normcorr  \
# 94       sub-3709                                          0.362625
# 95       sub-3700                                          0.138380
# 96       sub-3403                                        112.241258
# 97      sub-40733                                          0.046978
# 98     sub-116230                                          0.111927
# 99       sub-3620                                          0.268801
#
#     MAD_FLIRT_MNI152NLin2009cAsym_res-01_normcorr  \
# 94                                       0.429553
# 95                                       0.119692
# 96                                      39.083019
# 97                                       0.039653
# 98                                       0.381929
# 99                                       0.252074
#
#    QC_status_FLIRT_MNI152NLin2009cAsym_res-01_normcorr cohort
# 94                                             failed      PD
# ...

# %%
normcorr_df[normcorr_df["QC_status_FLIRT_MNI152NLin2009cAsym_res-01_normcorr"] == "fine"]
# Out:
#    Participant_ID  FD_std_FLIRT_MNI152NLin2009cAsym_res-01_normcorr  \
# 0       sub-40882                                          0.034352
# 1      sub-179784                                          0.026866
# 2       sub-75562                                          0.017651
# 3        sub-3001                                          0.015791
# 4        sub-3078                                          0.035090
# ..            ...                                               ...
# 89     sub-101039                                          0.018905
# 90       sub-3569                                          0.017384
# 91       sub-3112                                          0.051554
# 92       sub-3157                                          0.038673
# 93       sub-3852                                          0.042936
#
#     MAD_FLIRT_MNI152NLin2009cAsym_res-01_normcorr  \
# 0                                        0.030965
# ...

# %%
normmi_df
# Out:
#    Participant_ID  FD_std_FLIRT_MNI152NLin2009cAsym_res-01_normmi  \
# 0       sub-40882                                        0.199588
# 1      sub-179784                                        0.169951
# 2       sub-75562                                        1.093123
# 3        sub-3001                                        0.180874
# 4        sub-3078                                        0.310526
# ..            ...                                             ...
# 95       sub-3709                                        0.781292
# 96       sub-3700                                        1.852810
# 97      sub-40733                                        0.798495
# 98     sub-116230                                        0.375159
# 99       sub-3620                                      115.275273
#
#     MAD_FLIRT_MNI152NLin2009cAsym_res-01_normmi  \
# 0                                      0.215395
# 1                                      0.580648
# ...

# %%
normmi_df[normmi_df["FD_std_FLIRT_MNI152NLin2009cAsym_res-01_normmi"] > 0.2]
# Out:
#    Participant_ID  FD_std_FLIRT_MNI152NLin2009cAsym_res-01_normmi  \
# 2       sub-75562                                        1.093123
# 4        sub-3078                                        0.310526
# 5        sub-3403                                        1.786622
# 6      sub-139982                                        0.547363
# 7      sub-130156                                        0.412298
# ..            ...                                             ...
# 95       sub-3709                                        0.781292
# 96       sub-3700                                        1.852810
# 97      sub-40733                                        0.798495
# 98     sub-116230                                        0.375159
# 99       sub-3620                                      115.275273
#
#     MAD_FLIRT_MNI152NLin2009cAsym_res-01_normmi  \
# 2                                      0.872655
# 4                                      0.293834
# ...

# %%
np.mean(normmi_df[normmi_df["QC_status_FLIRT_MNI152NLin2009cAsym_res-01_normmi"] == "fine"]["FD_std_FLIRT_MNI152NLin2009cAsym_res-01_normmi"])
# Out:
# 0.3153851850992634

# %%
np.mean(normmi_df[normmi_df["QC_status_FLIRT_MNI152NLin2009cAsym_res-01_normmi"] == "failed"]["FD_std_FLIRT_MNI152NLin2009cAsym_res-01_normmi"])
# Out:
# 23.81660579993322

# %%
mutualinfo_df[mutualinfo_df["FD_std_FLIRT_MNI152NLin2009cAsym_res-01_mutualinfo"] > 0.2]
# Out:
#    Participant_ID  FD_std_FLIRT_MNI152NLin2009cAsym_res-01_mutualinfo  \
# 0       sub-40882                                           0.201775
# 1      sub-179784                                           0.330013
# 2       sub-75562                                           0.518250
# 3        sub-3001                                           0.219461
# 4        sub-3078                                           0.340902
# ..            ...                                                ...
# 95       sub-3403                                           1.013354
# 96      sub-40733                                           2.097067
# 97     sub-116230                                           2.530571
# 98       sub-3620                                         158.071841
# 99       sub-3853                                           6.572695
#
#     MAD_FLIRT_MNI152NLin2009cAsym_res-01_mutualinfo  \
# 0                                          0.169283
# ...

# %%
np.mean(mutualinfo_df[mutualinfo_df["QC_status_FLIRT_MNI152NLin2009cAsym_res-01_mutualinfo"] == "fine"]["FD_std_FLIRT_MNI152NLin2009cAsym_res-01_mutualinfo"])
# Out:
# 0.32290875974392913

# %%
np.mean(mutualinfo_df[mutualinfo_df["QC_status_FLIRT_MNI152NLin2009cAsym_res-01_mutualinfo"] == "failed"]["FD_std_FLIRT_MNI152NLin2009cAsym_res-01_mutualinfo"])
# Out:
# 31.67481599909481
